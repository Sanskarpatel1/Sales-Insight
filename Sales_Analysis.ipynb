# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %% [markdown]
# #### merging 12 files to one csv

# %%
path = "./Sales_Data"
files = [file for file in os.listdir(path) if not file.startswith('.')] # Ignore hidden files

all_months_data = pd.DataFrame()

for file in files:
    current_data = pd.read_csv(path+"/"+file)
    all_months_data = pd.concat([all_months_data, current_data])
    
all_months_data.to_csv("all_data_copy.csv", index=False)

# %%
all_data = pd.read_csv("all_data_copy.csv")
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# #### Cleaning the data

# %%
nan_df = all_data[all_data.isna().any(axis=1)]
display(nan_df.head())

all_data = all_data.dropna()
all_data.head()
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 1         NaN     NaN              NaN        NaN        NaN              NaN
# 356       NaN     NaN              NaN        NaN        NaN              NaN
# 735       NaN     NaN              NaN        NaN        NaN              NaN
# 1433      NaN     NaN              NaN        NaN        NaN              NaN
# 1553      NaN     NaN              NaN        NaN        NaN              NaN
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# #### get rid of text in order date column

# %%
all_data = all_data[all_data['Order Date'].str[0:2]!='Or'] ##There were "Or" word in date column

# %%
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])

# %% [markdown]
# #### add month column

# %%
all_data['Month'] = all_data['Order Date'].str[0:2]
all_data['Month'] = all_data['Month'].astype('int32')
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %% [markdown]
# #### add city column

# %%
def get_city(address):
    return address.split(",")[1].strip(" ")

def get_state(address):
    return address.split(",")[2].split(" ")[1]

all_data['City'] = all_data['Purchase Address'].apply(lambda x: f"{get_city(x)}  ({get_state(x)})")
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4
#
#                 City
# 0       Dallas  (TX)
# 2       Boston  (MA)
# 3  Los Angeles  (CA)
# 4  Los Angeles  (CA)
# 5  Los Angeles  (CA)

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# #### Question 1: What was the best month for sales? How much was earned that month?

# %%
all_data['Sales'] = all_data['Quantity Ordered'].astype('int') * all_data['Price Each'].astype('float')

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4
#
#                 City   Sales
# 0       Dallas  (TX)   23.90
# 2       Boston  (MA)   99.99
# 3  Los Angeles  (CA)  600.00
# 4  Los Angeles  (CA)   11.99
# 5  Los Angeles  (CA)   11.99

# %%
all_data.groupby(['Month']).sum()['Sales']
# Out:
# Month
# 1     1822256.73
# 2     2202022.42
# 3     2807100.38
# 4     3390670.24
# 5     3152606.75
# 6     2577802.26
# 7     2647775.76
# 8     2244467.88
# 9     2097560.13
# 10    3736726.88
# 11    3199603.20
# 12    4613443.34
# Name: Sales, dtype: float64

# %%
months = range(1,13)

plt.bar(months,all_data.groupby(['Month']).sum()['Sales'])
plt.xticks(months)
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month number')
plt.show()

# %% [markdown]
# #### Question 2: What city sold the most product?

# %%
cities=[city for city,df in all_data.groupby('City')]

plt.bar(cities,all_data.groupby(['City']).sum()['Sales'])
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month number')
plt.xticks(cities, rotation='vertical', size=8)
plt.show()

# %% [markdown]
# #### Question 3: What time should we display advertisements to maximize likelihood of customer's buying product?

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4
#
#                 City   Sales
# 0       Dallas  (TX)   23.90
# 2       Boston  (MA)   99.99
# 3  Los Angeles  (CA)  600.00
# 4  Los Angeles  (CA)   11.99
# 5  Los Angeles  (CA)   11.99

# %%
all_data['Order Date'] = pd.to_datetime(all_data['Order Date'], format='%m/%d/%y %H:%M')
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4
#
#                 City   Sales
# 0       Dallas  (TX)   23.90
# 2       Boston  (MA)   99.99
# 3  Los Angeles  (CA)  600.00
# 4  Los Angeles  (CA)   11.99
# 5  Los Angeles  (CA)   11.99

# %%
all_data['Hour'] = pd.to_datetime(all_data['Order Date']).dt.hour
all_data['Minute'] = pd.to_datetime(all_data['Order Date']).dt.minute
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4
#
#                 City   Sales  Hour  Minute
# 0       Dallas  (TX)   23.90     8      46
# 2       Boston  (MA)   99.99    22      30
# 3  Los Angeles  (CA)  600.00    14      38
# 4  Los Angeles  (CA)   11.99    14      38
# 5  Los Angeles  (CA)   11.99     9      27

# %%
hours = [hour for hour, df in all_data.groupby(['Hour'])]

plt.plot(hours, all_data.groupby(['Hour']).count())

plt.xlabel('hour')
plt.ylabel('Count of orders')

plt.grid()
#plt.xticks(hours)
plt.show()

# %% [markdown]
# #### Question 4: What products are most often sold together?

# %%
df = all_data[all_data['Order ID'].duplicated(keep=False)]
df.head(10)
# Out:
#     Order ID                     Product  Quantity Ordered  Price Each  \
# 3     176560                Google Phone                 1      600.00
# 4     176560            Wired Headphones                 1       11.99
# 18    176574                Google Phone                 1      600.00
# 19    176574        USB-C Charging Cable                 1       11.95
# 30    176585  Bose SoundSport Headphones                 1       99.99
# 31    176585  Bose SoundSport Headphones                 1       99.99
# 32    176586      AAA Batteries (4-pack)                 2        2.99
# 33    176586                Google Phone                 1      600.00
# 119   176672    Lightning Charging Cable                 1       14.95
# 120   176672        USB-C Charging Cable                 1       11.95
#
#              Order Date                        Purchase Address  Month  \
# 3   2019-04-12 14:38:00    669 Spruce St, Los Angeles, CA 90001      4
# 4   2019-04-12 14:38:00    669 Spruce St, Los Angeles, CA 90001      4
# 18  2019-04-03 19:42:00       20 Hill St, Los Angeles, CA 90001      4
# 19  2019-04-03 19:42:00       20 Hill St, Los Angeles, CA 90001      4
# 30  2019-04-07 11:31:00       823 Highland St, Boston, MA 02215      4
# 31  2019-04-07 11:31:00       823 Highland St, Boston, MA 02215      4
# 32  2019-04-10 17:00:00  365 Center St, San Francisco, CA 94016      4
# 33  2019-04-10 17:00:00  365 Center St, San Francisco, CA 94016      4
# 119 2019-04-12 11:07:00   778 Maple St, New York City, NY 10001      4
# 120 2019-04-12 11:07:00   778 Maple St, New York City, NY 10001      4
#
#                     City   Sales  Hour  Minute
# 3      Los Angeles  (CA)  600.00    14      38
# 4      Los Angeles  (CA)   11.99    14      38
# 18     Los Angeles  (CA)  600.00    19      42
# 19     Los Angeles  (CA)   11.95    19      42
# 30          Boston  (MA)   99.99    11      31
# 31          Boston  (MA)   99.99    11      31
# 32   San Francisco  (CA)    5.98    17       0
# 33   San Francisco  (CA)  600.00    17       0
# 119  New York City  (NY)   14.95    11       7
# 120  New York City  (NY)   11.95    11       7

# %%
df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
# Out:
# C:\Users\Prakhar\AppData\Local\Temp\ipykernel_8964\2345761670.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))

# %%
df.head(10)
# Out:
#     Order ID                     Product  Quantity Ordered  Price Each  \
# 3     176560                Google Phone                 1      600.00
# 4     176560            Wired Headphones                 1       11.99
# 18    176574                Google Phone                 1      600.00
# 19    176574        USB-C Charging Cable                 1       11.95
# 30    176585  Bose SoundSport Headphones                 1       99.99
# 31    176585  Bose SoundSport Headphones                 1       99.99
# 32    176586      AAA Batteries (4-pack)                 2        2.99
# 33    176586                Google Phone                 1      600.00
# 119   176672    Lightning Charging Cable                 1       14.95
# 120   176672        USB-C Charging Cable                 1       11.95
#
#              Order Date                        Purchase Address  Month  \
# 3   2019-04-12 14:38:00    669 Spruce St, Los Angeles, CA 90001      4
# 4   2019-04-12 14:38:00    669 Spruce St, Los Angeles, CA 90001      4
# 18  2019-04-03 19:42:00       20 Hill St, Los Angeles, CA 90001      4
# 19  2019-04-03 19:42:00       20 Hill St, Los Angeles, CA 90001      4
# 30  2019-04-07 11:31:00       823 Highland St, Boston, MA 02215      4
# 31  2019-04-07 11:31:00       823 Highland St, Boston, MA 02215      4
# 32  2019-04-10 17:00:00  365 Center St, San Francisco, CA 94016      4
# 33  2019-04-10 17:00:00  365 Center St, San Francisco, CA 94016      4
# 119 2019-04-12 11:07:00   778 Maple St, New York City, NY 10001      4
# 120 2019-04-12 11:07:00   778 Maple St, New York City, NY 10001      4
#
#                     City   Sales  Hour  Minute  \
# 3      Los Angeles  (CA)  600.00    14      38
# 4      Los Angeles  (CA)   11.99    14      38
# 18     Los Angeles  (CA)  600.00    19      42
# 19     Los Angeles  (CA)   11.95    19      42
# 30          Boston  (MA)   99.99    11      31
# 31          Boston  (MA)   99.99    11      31
# 32   San Francisco  (CA)    5.98    17       0
# 33   San Francisco  (CA)  600.00    17       0
# 119  New York City  (NY)   14.95    11       7
# 120  New York City  (NY)   11.95    11       7
#
#                                                Grouped
# 3                        Google Phone,Wired Headphones
# 4                        Google Phone,Wired Headphones
# 18                   Google Phone,USB-C Charging Cable
# 19                   Google Phone,USB-C Charging Cable
# 30   Bose SoundSport Headphones,Bose SoundSport Hea...
# 31   Bose SoundSport Headphones,Bose SoundSport Hea...
# 32                 AAA Batteries (4-pack),Google Phone
# 33                 AAA Batteries (4-pack),Google Phone
# 119      Lightning Charging Cable,USB-C Charging Cable
# 120      Lightning Charging Cable,USB-C Charging Cable

# %%
df = df[['Order ID', 'Grouped']].drop_duplicates()

# %%
df.head()
# Out:
#     Order ID                                            Grouped
# 3     176560                      Google Phone,Wired Headphones
# 18    176574                  Google Phone,USB-C Charging Cable
# 30    176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 32    176586                AAA Batteries (4-pack),Google Phone
# 119   176672      Lightning Charging Cable,USB-C Charging Cable

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in df['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

for key,value in count.most_common(10):
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# #### What product sold the most?

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4
#
#                 City   Sales  Hour  Minute
# 0       Dallas  (TX)   23.90     8      46
# 2       Boston  (MA)   99.99    22      30
# 3  Los Angeles  (CA)  600.00    14      38
# 4  Los Angeles  (CA)   11.99    14      38
# 5  Los Angeles  (CA)   11.99     9      27

# %%
all_data.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered             int64
# Price Each                 float64
# Order Date          datetime64[ns]
# Purchase Address            object
# Month                        int32
# City                        object
# Sales                      float64
# Hour                         int32
# Minute                       int32
# dtype: object

# %%
product_group = all_data.groupby('Product')
grouped_sum = product_group.sum(numeric_only=True)
quantity_ordered = grouped_sum['Quantity Ordered']

keys = [pair for pair, df in product_group]
plt.bar(keys, quantity_ordered)
plt.xticks(keys, rotation='vertical', size=8)
plt.show()

# %%
prices = all_data.groupby('Product')['Price Each'].mean()
print(prices)
# Out:
# Product
# 20in Monitor                   109.99
# 27in 4K Gaming Monitor         389.99
# 27in FHD Monitor               149.99
# 34in Ultrawide Monitor         379.99
# AA Batteries (4-pack)            3.84
# AAA Batteries (4-pack)           2.99
# Apple Airpods Headphones       150.00
# Bose SoundSport Headphones      99.99
# Flatscreen TV                  300.00
# Google Phone                   600.00
# LG Dryer                       600.00
# LG Washing Machine             600.00
# Lightning Charging Cable        14.95
# Macbook Pro Laptop            1700.00
# ThinkPad Laptop                999.99
# USB-C Charging Cable            11.95
# Vareebadd Phone                400.00
# Wired Headphones                11.99
# iPhone                         700.00
# Name: Price Each, dtype: float64

# %%
prices = all_data.groupby('Product')['Price Each'].mean()

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(keys, quantity_ordered, color='g')
ax2.plot(keys, prices, color='b')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered', color='g')
ax2.set_ylabel('Price ($)', color='b')
ax1.set_xticklabels(keys, rotation='vertical', size=8)

fig.show()
# Out:
# C:\Users\Prakhar\AppData\Local\Temp\ipykernel_8964\1237057308.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(keys, rotation='vertical', size=8)
# C:\Users\Prakhar\AppData\Local\Temp\ipykernel_8964\1237057308.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
all_data.head(50)
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 2    176559  Bose SoundSport Headphones                 1       99.99
# 3    176560                Google Phone                 1      600.00
# 4    176560            Wired Headphones                 1       11.99
# 5    176561            Wired Headphones                 1       11.99
# 6    176562        USB-C Charging Cable                 1       11.95
# 7    176563  Bose SoundSport Headphones                 1       99.99
# 8    176564        USB-C Charging Cable                 1       11.95
# 9    176565          Macbook Pro Laptop                 1     1700.00
# 10   176566            Wired Headphones                 1       11.99
# 11   176567                Google Phone                 1      600.00
# 12   176568    Lightning Charging Cable                 1       14.95
# 13   176569      27in 4K Gaming Monitor                 1      389.99
# 14   176570       AA Batteries (4-pack)                 1        3.84
# 15   176571    Lightning Charging Cable                 1       14.95
# 16   176572    Apple Airpods Headphones                 1      150.00
# 17   176573        USB-C Charging Cable                 1       11.95
# 18   176574                Google Phone                 1      600.00
# 19   176574        USB-C Charging Cable                 1       11.95
# 20   176575      AAA Batteries (4-pack)                 1        2.99
# 21   176576    Apple Airpods Headphones                 1      150.00
# 22   176577    Apple Airpods Headphones                 1      150.00
# 23   176578    Apple Airpods Headphones                 1      150.00
# 24   176579       AA Batteries (4-pack)                 1        3.84
# 25   176580        USB-C Charging Cable                 1       11.95
# 26   176581                      iPhone                 1      700.00
# 27   176582  Bose SoundSport Headphones                 1       99.99
# 28   176583      AAA Batteries (4-pack)                 2        2.99
# 29   176584               Flatscreen TV                 1      300.00
# 30   176585  Bose SoundSport Headphones                 1       99.99
# 31   176585  Bose SoundSport Headphones                 1       99.99
# 32   176586      AAA Batteries (4-pack)                 2        2.99
# 33   176586                Google Phone                 1      600.00
# 34   176587            27in FHD Monitor                 1      149.99
# 35   176588                20in Monitor                 1      109.99
# 36   176589    Lightning Charging Cable                 1       14.95
# 37   176590                Google Phone                 1      600.00
# 38   176591    Apple Airpods Headphones                 1      150.00
# 39   176592        USB-C Charging Cable                 1       11.95
# 40   176593    Lightning Charging Cable                 2       14.95
# 41   176594            Wired Headphones                 1       11.99
# 42   176595            Wired Headphones                 3       11.99
# 43   176596    Apple Airpods Headphones                 1      150.00
# 44   176597        USB-C Charging Cable                 1       11.95
# 45   176598      AAA Batteries (4-pack)                 2        2.99
# 46   176599    Lightning Charging Cable                 1       14.95
# 47   176600      27in 4K Gaming Monitor                 1      389.99
# 48   176601        USB-C Charging Cable                 1       11.95
# 49   176602    Lightning Charging Cable                 1       14.95
# 50   176603        USB-C Charging Cable                 1       11.95
#
#             Order Date                           Purchase Address  Month  \
# 0  2019-04-19 08:46:00               917 1st St, Dallas, TX 75001      4
# 2  2019-04-07 22:30:00          682 Chestnut St, Boston, MA 02215      4
# 3  2019-04-12 14:38:00       669 Spruce St, Los Angeles, CA 90001      4
# 4  2019-04-12 14:38:00       669 Spruce St, Los Angeles, CA 90001      4
# 5  2019-04-30 09:27:00          333 8th St, Los Angeles, CA 90001      4
# 6  2019-04-29 13:03:00     381 Wilson St, San Francisco, CA 94016      4
# 7  2019-04-02 07:46:00           668 Center St, Seattle, WA 98101      4
# 8  2019-04-12 10:58:00            790 Ridge St, Atlanta, GA 30301      4
# 9  2019-04-24 10:38:00     915 Willow St, San Francisco, CA 94016      4
# 10 2019-04-08 14:05:00                83 7th St, Boston, MA 02215      4
# 11 2019-04-18 17:18:00          444 7th St, Los Angeles, CA 90001      4
# 12 2019-04-15 12:18:00              438 Elm St, Seattle, WA 98101      4
# 13 2019-04-16 19:23:00              657 Hill St, Dallas, TX 75001      4
# 14 2019-04-22 15:09:00              186 12th St, Dallas, TX 75001      4
# 15 2019-04-19 14:29:00          253 Johnson St, Atlanta, GA 30301      4
# 16 2019-04-04 20:30:00    149 Dogwood St, New York City, NY 10001      4
# 17 2019-04-27 18:41:00   214 Chestnut St, San Francisco, CA 94016      4
# 18 2019-04-03 19:42:00          20 Hill St, Los Angeles, CA 90001      4
# 19 2019-04-03 19:42:00          20 Hill St, Los Angeles, CA 90001      4
# 20 2019-04-27 00:30:00       433 Hill St, New York City, NY 10001      4
# 21 2019-04-28 11:42:00        771 Ridge St, Los Angeles, CA 90001      4
# 22 2019-04-04 19:25:00            260 Spruce St, Dallas, TX 75001      4
# 23 2019-04-09 23:35:00            513 Church St, Boston, MA 02215      4
# 24 2019-04-11 10:23:00  886 Jefferson St, New York City, NY 10001      4
# 25 2019-04-05 00:35:00       886 Willow St, Los Angeles, CA 90001      4
# 26 2019-04-09 21:38:00            84 Jackson St, Boston, MA 02215      4
# 27 2019-04-27 12:20:00          178 Lincoln St, Atlanta, GA 30301      4
# 28 2019-04-20 12:00:00         146 Jackson St, Portland, OR 97035      4
# 29 2019-04-24 20:39:00     936 Church St, San Francisco, CA 94016      4
# 30 2019-04-07 11:31:00          823 Highland St, Boston, MA 02215      4
# 31 2019-04-07 11:31:00          823 Highland St, Boston, MA 02215      4
# 32 2019-04-10 17:00:00     365 Center St, San Francisco, CA 94016      4
# 33 2019-04-10 17:00:00     365 Center St, San Francisco, CA 94016      4
# 34 2019-04-29 19:38:00          557 5th St, Los Angeles, CA 90001      4
# 35 2019-04-02 04:00:00           765 Cherry St, Seattle, WA 98101      4
# 36 2019-04-04 12:23:00         846 Highland St, Atlanta, GA 30301      4
# 37 2019-04-11 11:46:00        873 6th St, New York City, NY 10001      4
# 38 2019-04-21 07:21:00             600 Maple St, Austin, TX 73301      4
# 39 2019-04-27 13:04:00          352 4th St, Los Angeles, CA 90001      4
# 40 2019-04-15 13:45:00             906 7th St, Portland, OR 97035      4
# 41 2019-04-17 23:04:00       63 Maple St, San Francisco, CA 94016      4
# 42 2019-04-02 09:11:00          383 6th St, Los Angeles, CA 90001      4
# 43 2019-04-27 20:11:00            572 Meadow St, Dallas, TX 75001      4
# 44 2019-04-19 13:39:00       681 11th St, San Francisco, CA 94016      4
# 45 2019-04-21 20:33:00       294 Park St, San Francisco, CA 94016      4
# 46 2019-04-11 15:25:00      279 Maple St, New York City, NY 10001      4
# 47 2019-04-30 15:54:00               87 West St, Boston, MA 02215      4
# 48 2019-04-02 22:32:00         754 10th St, Los Angeles, CA 90001      4
# 49 2019-04-30 09:39:00           9 Jefferson St, Dallas, TX 75001      4
# 50 2019-04-01 07:46:00        858 6th St, San Francisco, CA 94016      4
#
#                    City    Sales  Hour  Minute
# 0          Dallas  (TX)    23.90     8      46
# 2          Boston  (MA)    99.99    22      30
# 3     Los Angeles  (CA)   600.00    14      38
# 4     Los Angeles  (CA)    11.99    14      38
# 5     Los Angeles  (CA)    11.99     9      27
# 6   San Francisco  (CA)    11.95    13       3
# 7         Seattle  (WA)    99.99     7      46
# 8         Atlanta  (GA)    11.95    10      58
# 9   San Francisco  (CA)  1700.00    10      38
# 10         Boston  (MA)    11.99    14       5
# 11    Los Angeles  (CA)   600.00    17      18
# 12        Seattle  (WA)    14.95    12      18
# 13         Dallas  (TX)   389.99    19      23
# 14         Dallas  (TX)     3.84    15       9
# 15        Atlanta  (GA)    14.95    14      29
# 16  New York City  (NY)   150.00    20      30
# 17  San Francisco  (CA)    11.95    18      41
# 18    Los Angeles  (CA)   600.00    19      42
# 19    Los Angeles  (CA)    11.95    19      42
# 20  New York City  (NY)     2.99     0      30
# 21    Los Angeles  (CA)   150.00    11      42
# 22         Dallas  (TX)   150.00    19      25
# 23         Boston  (MA)   150.00    23      35
# 24  New York City  (NY)     3.84    10      23
# 25    Los Angeles  (CA)    11.95     0      35
# 26         Boston  (MA)   700.00    21      38
# 27        Atlanta  (GA)    99.99    12      20
# 28       Portland  (OR)     5.98    12       0
# 29  San Francisco  (CA)   300.00    20      39
# 30         Boston  (MA)    99.99    11      31
# 31         Boston  (MA)    99.99    11      31
# 32  San Francisco  (CA)     5.98    17       0
# 33  San Francisco  (CA)   600.00    17       0
# 34    Los Angeles  (CA)   149.99    19      38
# 35        Seattle  (WA)   109.99     4       0
# 36        Atlanta  (GA)    14.95    12      23
# 37  New York City  (NY)   600.00    11      46
# 38         Austin  (TX)   150.00     7      21
# 39    Los Angeles  (CA)    11.95    13       4
# 40       Portland  (OR)    29.90    13      45
# 41  San Francisco  (CA)    11.99    23       4
# 42    Los Angeles  (CA)    35.97     9      11
# 43         Dallas  (TX)   150.00    20      11
# 44  San Francisco  (CA)    11.95    13      39
# 45  San Francisco  (CA)     5.98    20      33
# 46  New York City  (NY)    14.95    15      25
# 47         Boston  (MA)   389.99    15      54
# 48    Los Angeles  (CA)    11.95    22      32
# 49         Dallas  (TX)    14.95     9      39
# 50  San Francisco  (CA)    11.95     7      46
